# %%
from sklearn.metrics import cohen_kappa_score

# Labels provided by two annotators
annotator1 = ['A', 'B', 'C', 'A', 'B', 'C', 'A', 'A', 'B', 'C']
annotator2 = ['A', 'B', 'C', 'A', 'C', 'C', 'B', 'A', 'B', 'A']

# Compute Cohen's Kappa
kappa = cohen_kappa_score(annotator1, annotator2)
print(f"Cohen's Kappa: {kappa:.4f}")

# %%
annotator1 =['Reducing_Prompting_Expertise',
'Well_Calibrated_Abstention',
'Hedging_Language',
'Reducing_Prompting_Expertise',
'Effective_Routing',
'Reducing_Prompting_Expertise',
'Effective_Routing',
'Reducing_Prompting_Expertise',
'User_Attributes',
'Range_of_Viewpoints',
'Reducing_Prompting_Expertise',
'Reducing_Prompting_Expertise',
'User_Attributes',
'Range_of_Viewpoints',
'Minimizing_Sycophancy',
'User_Attributes',
'Reducing_Prompting_Expertise',
'Well_Calibrated_Abstention',
'Range_of_Viewpoints',
'User_Attributes',
'Effective_Routing',
'Citation_Reference_Verification',
'Reducing_Prompting_Expertise',
'Well_Calibrated_Abstention',
'Ambiguity_Resolution',
'Reducing_Prompting_Expertise',
'Ambiguity_Resolution',
'Identifying_Frame_Dependence',
'Well_Calibrated_Abstention',
'Reducing_Prompting_Expertise',
'Effective_Routing',
'Reducing_Prompting_Expertise',
'Range_of_Viewpoints',
'Ambiguity_Resolution',
'Range_of_Viewpoints',
'Ambiguity_Resolution',
'Reducing_Prompting_Expertise',
'Reducing_Prompting_Expertise',
'User_Attributes',
'Identifying_Frame_Dependence',
'Hedging_Language',
'Reducing_Prompting_Expertise',
'User_Attributes',
'Reducing_Prompting_Expertise',
'Hedging_Language',
'User_Attributes',
'Range_of_Viewpoints',
'Ambiguity_Resolution',
'Reducing_Prompting_Expertise',
'Ambiguity_Resolution',
'Range_of_Viewpoints',
'Minimizing_Sycophancy']



annotator2 =['Reducing_Prompting_Expertise',
'Well_Calibrated_Abstention',
'Hedging_Language',
'Reducing_Prompting_Expertise',
'Effective_Routing',
'Reducing_Prompting_Expertise',
'None',
'Reducing_Prompting_Expertise',
'User_Attributes',
'Range_of_Viewpoints',
'Reducing_Prompting_Expertise',
'Reducing_Prompting_Expertise',
'User_Attributes',
'Range_of_Viewpoints',
'Minimizing_Sycophancy',
'User_Attributes',
'Reducing_Prompting_Expertise',
'Hedging_Language',
'Range_of_Viewpoints',
'User_Attributes',
'Effective_Routing',
'Citation_Reference_Verification',
'Reducing_Prompting_Expertise',
'Well_Calibrated_Abstention',
'Ambiguity_Resolution',
'Identifying_Frame_Dependence',
'Ambiguity_Resolution',
'Identifying_Frame_Dependence',
'Well_Calibrated_Abstention',
'Identifying_Frame_Dependence',
'Effective_Routing',
'Identifying_Frame_Dependence',
'Range_of_Viewpoints',
'Ambiguity_Resolution',
'Range_of_Viewpoints',
'Ambiguity_Resolution',
'Reducing_Prompting_Expertise',
'Reducing_Prompting_Expertise',
'User_Attributes',
'Identifying_Frame_Dependence',
'Hedging_Language',
'Reducing_Prompting_Expertise',
'User_Attributes',
'Reducing_Prompting_Expertise',
'Hedging_Language',
'User_Attributes',
'Range_of_Viewpoints',
'Ambiguity_Resolution',
'Reducing_Prompting_Expertise',
'Ambiguity_Resolution',
'Range_of_Viewpoints',
'Minimizing_Sycophancy']

# %%
from sklearn.metrics import cohen_kappa_score

# # Labels provided by two annotators
# annotator1 = ['A', 'B', 'C', 'A', 'B', 'C', 'A', 'A', 'B', 'C']
# annotator2 = ['A', 'B', 'C', 'A', 'C', 'C', 'B', 'A', 'B', 'A']

# Compute Cohen's Kappa
kappa = cohen_kappa_score(annotator1, annotator2)
print(f"Cohen's Kappa: {kappa:.4f}")
# Out:
# Cohen's Kappa: 0.8875
